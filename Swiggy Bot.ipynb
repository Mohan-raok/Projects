# %% [markdown]
# # Swiggy Bot
#
#     $welcome msg [user name]
#
#     $replay for Questions {food questions}
#
#     $end- close application

# %%
Customer_Name = str(input('Enter your name:'))
print('welcome',Customer_Name)
Q1 = input('what do you like to order?')
if Q1.lower() == 'veg biryani':
    print('mixed veg biryani, paneer biryani, mushroom biryani')
elif Q1.lower() == 'non veg biryani':
    print('chicken biryani, prawns biryani')
else:
    print('Currently this item is not available')
# Out:
# Enter your name:mohan
# welcome mohan
# what do you like to order?veg biryani
# mixed veg biryani, paneer biryani, mushroom biryani

# %%
Customer_Name = input("Enter your name:")
print("Welcome",Customer_Name)
print("'Eat what makes you happy'")
print("Here is the menu")
print("Manchurian\nNoodles\nPizza\nBiryani\nBurger\nCake\nChaat\nShawarma\nShakes\nSandwich\nPastry")
Order = input("Select an item :")
print("Here are the restaurants delivering the items and their price",Order)
class Restaurant:
    def __init__(self,Restaurant,Manchuria,Noodles,Pizza,Biryani,Burger):
        self.Restaurant=Restaurant
        self.Manchuria=Manchuria
        self.Noodles=Noodles
        self.Pizza=Pizza
        self.Biryani=Biryani
        self.Burger=Burger
    def display(self):
        print('Restaurant:',self.Restaurant)
        print('Manchuria:',self.Manchuria)
        print('Noodles:',self.Noodles)
        print('Pizza:',self.Pizza)
        print('Biryani:',self.Biryani)
        print('Burger:',self.Burger)
        print('.................')

obj1=Restaurant('Spice House',100,110,120,130,140)
obj1.display()
        
obj2=Restaurant('Lavish Lounge',105,110,125,130,140)
obj2.display()

obj3=Restaurant('Royal Spicy Foods',105,110,120,130,150)
obj3.display()

obj4=Restaurant('Food Paradise',90,110,120,135,140)
obj4.display()

Bot = input('Anything else do you like to order?')
if Bot.lower() == 'no':
    print('Thank you for visiting')
else:
    print('continue')
# Out:
# Enter your name:mohan
# Welcome mohan
# 'Eat what makes you happy'
# Here is the menu
# Manchurian
# Noodles
# Pizza
# Biryani
# Burger
# Cake
# Chaat
# Shawarma
# Shakes
# Sandwich
# Pastry
# Select an item :biryani
# Here are the restaurants delivering the items and their price biryani
# Restaurant: Spice House
# Manchuria: 100
# Noodles: 110
# Pizza: 120
# Biryani: 130
# Burger: 140
# .................
# Restaurant: Lavish Lounge
# Manchuria: 105
# Noodles: 110
# Pizza: 125
# Biryani: 130
# Burger: 140
# .................
# Restaurant: Royal Spicy Foods
# Manchuria: 105
# Noodles: 110
# Pizza: 120
# Biryani: 130
# Burger: 150
# .................
# Restaurant: Food Paradise
# Manchuria: 90
# Noodles: 110
# Pizza: 120
# Biryani: 135
# Burger: 140
# .................

# %%
class Restaurant:
    def __init__(self,Manchuria,Noodles,Pizza,Biryani,Burger):
        self.Manchuria=Manchuria
        self.Noodles=Noodles
        self.Pizza=Pizza
        self.Biryani=Biryani
        self.Burger=Burger
    def display(self):
        print('Manchuria:',self.Manchuria)
        print('Noodles:',self.Noodles)
        print('Pizza:',self.Pizza)
        print('Biryani:',self.Biryani)
        print('Burger:',self.Burger)
        print('.................')
        
Spice_House_Restaurant=Restaurant(100,110,120,130,140)
Spice_House_Restaurant.display()
        
Lavish_Lounge=Restaurant(100,110,120,130,140)
Lavish_Lounge.display()

Royal_Spicy_Foods=Restaurant(100,110,120,130,140)
Royal_Spicy_Foods.display()

Food_Paradise=Restaurant(100,110,120,130,140)
Food_Paradise.display()
# Out:
# Manchuria: 100
# Noodles: 110
# Pizza: 120
# Biryani: 130
# Burger: 140
# .................
# Manchuria: 100
# Noodles: 110
# Pizza: 120
# Biryani: 130
# Burger: 140
# .................
# Manchuria: 100
# Noodles: 110
# Pizza: 120
# Biryani: 130
# Burger: 140
# .................
# Manchuria: 100
# Noodles: 110
# Pizza: 120
# Biryani: 130
# Burger: 140
# .................

# %%
Customer_Name = input("Enter your name:")
print("Welcome",Customer_Name)
print("'Eat what makes you happy'")
#Restaurant = 
Menu = '''
manchurian   Rs 100
noodles      Rs 50
pizza        Rs 100
biryani      Rs 200
burger       Rs 100
cake         Rs 50
chaat        Rs 50
shawarma     Rs 100
shakes       Rs 50
sandwich     Rs 50
pastry       Rs 60
'''
Special_Dish_of_the_day = "veg thali  Rs 80"


option = int(input('For Menu Press 1, For Special_Dish_of_the_day Press 2:'))
if option == 1:
    print(Menu)
if option == 2:
    print(Special_Dish_of_the_day)
for i in range(len(Menu)):
    Bot = int(input('press 1 to order  otherwise press 2 to exit:'))
    if Bot == 2:
        print('"Thanks for visiting, Have a Great day"')
        break

    elif Bot == 1:
        order = input('Enter your food items:')
        for order in Menu or Special_Dish_of_the_day :
            Quantity = int(input('Enter Quantity of food item required:'))
       # else:
           # print('Sorry, the entered item is currently not available')

# %%
Menu = ''' 
           Manchurian
           Noodles
           Pizza
           Biryani
           Burger
           Cake
           Chaat
           Shawarma
           Shakes
           Sandwich
           Pastry
         '''

# %%
# Out:
# Welcome to Royal Spice Foods
# ['manchuria', 'Noodles', 'Chat', 'burger', 'pizza']
# manchuria 200
# Noodles 150
# Chat 100
# burger 250
# pizza 150
# PRESS E TO GET BILL
# enter you orderpizza
# manchuria 200
# Noodles 150
# Chat 100
# burger 250
# pizza 150
# PRESS E TO GET BILL
# enter you orderChat
# manchuria 200
# Noodles 150
# Chat 100
# burger 250
# pizza 150
# PRESS E TO GET BILL

# %%
Customer_Name = input("Enter your name:")
print("Welcome",Customer_Name)
print("'Eat what makes you happy'")
Menu = """\n1.manchurian of Rs= 100
2.noodles  of Rs=    50
3.pizza of Rs=      140
4.biryani of Rs=    200
5.burger of Rs=     150
6.cake of Rs=       90
7.chaat of Rs=      60
8.shawarma of Rs=   120
9.shakes of Rs=     60
10.sandwich of Rs=  60
11.pastry of Rs=    70
"""
option=int(input("enter 1 to order an iteam in this resturent and 2 to exit  = "))

if option==1:
          print("-----------------WELCOME TO BAHAR BIRYANI CAFE-----------------------")
if option==2:
        print("please visit another regvvxvvdvgd")
        break

iteams={"manchurian" : 100,
"noodles" :50,
"pizza"    : 140,
"biryani"   : 200,
"burger"     : 150,
"cake"    :  90,
"chaat"    : 60,
"shawarma"  : 120,
"shakes "  : 60,
"sandwich" : 60,
"pastry"    : 70}
Special_Dish_of_the_day = "veg thali"


option = int(input('For Menu Press 1, For Special_Dish_of_the_day Press 2:'))
if option == 1:
    print(Menu)
if option == 2:
    print(Special_Dish_of_the_day)
for i in range(len(Menu)):
    Bot = int(input('press 1 to order  otherwise press 2 to exit:'))
    if Bot == 2:
        print('"Thanks for visiting, Have a Great day"')
        break

    elif Bot == 1:
        order = input('Enter your food items:')
        if order in Menu:
            Quantity = int(input('Enter Quantity of food item required:'))
        if order in iteams.keys():
            price=Quantity*(iteams[order])
            print(price)
        else:
            print('Sorry, the entered item is currently not available')
    elif option==12:
        print("please visit another regvvxvvdvgd")
# Out:
# Enter your name:mohan
# Welcome mohan
# 'Eat what makes you happy'
# enter 1 to order an iteam in this resturent and 2 to exit  = 1
# -----------------WELCOME TO BAHAR BIRYANI CAFE-----------------------
#   File "<ipython-input-2-39f98c8d5dcc>", line 22
#     break
#     ^
# SyntaxError: 'break' outside loop

# %%
Customer_Name = input("Enter your name:")
print("Welcome",Customer_Name)
print("'Eat what makes you happy'")

class Restaurant:
    def __init__(self,Restaurant_Name,Manchuria,Noodles,Pizza,Biryani,Burger,Cake,Chaat,Shawarma,Shakes,Sandwich,Pastry):
        self.Restaurant_Name=Restaurant_Name
        self.Manchuria=Manchuria
        self.Noodles=Noodles
        self.Pizza=Pizza
        self.Biryani=Biryani
        self.Burger=Burger
        self.Cake=Cake
        self.Chaat=Chaat
        self.Shawarma=Shawarma
        self.Shakes=Shakes
        self.Sandwich=Sandwich
        self.Pastry=Pastry
    def display(self):
        print('Restaurant_Name:',self.Restaurant_Name)
        print('Manchuria:',self.Manchuria)
        print('Noodles:',self.Noodles)
        print('Pizza:',self.Pizza)
        print('Biryani:',self.Biryani)
        print('Burger:',self.Burger)
        print('Cake:',self.Cake)
        print('Chaat:',self.Chaat)
        print('Shawarma:',self.Shawarma)
        print('Shakes:',self.Shakes)
        print('Sandwich:',self.Sandwich)
        print('Pastry:',self.Pastry)
        print('.................')
        
Choose_Restaurant = int(input("""
                                 Press 1  For 'Spice_House_Restaurant'   
                                 Press 2  For 'Lavish_Lounge_Restaurant' 
                                 Press 3  For 'Royal_Spicy_Foods_Restaurant' 
                                 Press 4  For 'Food_Paradise_Restaurant' :
                                 """))
if Choose_Restaurant == 1:
    Menu1 = '''
manchurian   Rs 100
noodles      Rs 50
pizza        Rs 100
biryani      Rs 200
burger       Rs 100
cake         Rs 50
chaat        Rs 50
shawarma     Rs 100
shakes       Rs 50
sandwich     Rs 50
pastry       Rs 60
'''
    print('***Spice_House_Restaurant***')
    print(Menu1)
    for i in range(len(Menu1)):
        Bot = int(input('press 1 to order  otherwise press 2 to exit:'))
        if Bot == 2:
            print('"Thanks for visiting, Have a Great day"')
            break
        elif Bot == 1:
            order = input('Enter your food items:')
            if order in Menu1 or Special_Dish_of_the_day :
                Quantity = int(input('Enter Quantity of food item required:'))
            else:
                print('Sorry, the entered item is currently not available')
   # Spice_House_Restaurant=Restaurant('***Spice_House_Restaurant***',100,110,120,130,140,50,60,50,60,70,80)
   # Spice_House_Restaurant.display()
    
if Choose_Restaurant == 2: 
    Lavish_Lounge_Restaurant=Restaurant('***Lavish_Lounge_Restaurant***',100,110,120,130,140,50,60,50,60,70,80)
    Lavish_Lounge_Restaurant.display()
if Choose_Restaurant == 3:
    Royal_Spicy_Foods_Restaurant=Restaurant('***Royal_Spicy_Foods_Restaurant***',100,110,120,130,140,50,60,50,60,70,80)
    Royal_Spicy_Foods_Restaurant.display()
if Choose_Restaurant == 4:
    Food_Paradise_Restaurant=Restaurant('***Food_Paradise_Restaurant***',100,110,120,130,140,50,60,50,60,70,80)
    Food_Paradise_Restaurant.display()
    
for i in range(len(Restaurant)):
    Bot = int(input('press 1 to order  otherwise press 2 to exit:'))
    if Bot == 2:
        print('"Thanks for visiting, Have a Great day"')
        break
    elif Bot == 1:
        order = input('Enter your food items:')
        if order in Menu1 or Special_Dish_of_the_day :
            Quantity = int(input('Enter Quantity of food item required:'))
        else:
            print('Sorry, the entered item is currently not available')

# %%
Customer_Name = input("Enter your name:")
print("Welcome",Customer_Name)
print("'Eat what makes you happy'")

class Restaurant:
    def __init__(self,Restaurant_Name,Manchuria,Noodles,Pizza,Biryani,Burger,Cake,Chaat,Shawarma,Shakes,Sandwich,Pastry):
        self.Restaurant_Name=Restaurant_Name
        self.Manchuria=Manchuria
        self.Noodles=Noodles
        self.Pizza=Pizza
        self.Biryani=Biryani
        self.Burger=Burger
        self.Cake=Cake
        self.Chaat=Chaat
        self.Shawarma=Shawarma
        self.Shakes=Shakes
        self.Sandwich=Sandwich
        self.Pastry=Pastry
    def display(self):
        print('Restaurant_Name:',self.Restaurant_Name)
        print('Manchuria:',self.Manchuria)
        print('Noodles:',self.Noodles)
        print('Pizza:',self.Pizza)
        print('Biryani:',self.Biryani)
        print('Burger:',self.Burger)
        print('Cake:',self.Cake)
        print('Chaat:',self.Chaat)
        print('Shawarma:',self.Shawarma)
        print('Shakes:',self.Shakes)
        print('Sandwich:',self.Sandwich)
        print('Pastry:',self.Pastry)
        print('.................')
        
Choose_Restaurant = int(input("""
                                 Press 1  For 'Spice_House_Restaurant'   
                                 Press 2  For 'Lavish_Lounge_Restaurant' 
                                 Press 3  For 'Royal_Spicy_Foods_Restaurant' 
                                 Press 4  For 'Food_Paradise_Restaurant' :
                                 """))
if Choose_Restaurant == 1:
    Spice_House_Restaurant=Restaurant('***Spice_House_Restaurant***',100,110,120,130,140,50,60,50,60,70,80)
    Spice_House_Restaurant.display()
if Choose_Restaurant == 2: 
    Lavish_Lounge_Restaurant=Restaurant('***Lavish_Lounge_Restaurant***',100,110,120,130,140,50,60,50,60,70,80)
    Lavish_Lounge_Restaurant.display()
if Choose_Restaurant == 3:
    Royal_Spicy_Foods_Restaurant=Restaurant('***Royal_Spicy_Foods_Restaurant***',100,110,120,130,140,50,60,50,60,70,80)
    Royal_Spicy_Foods_Restaurant.display()
if Choose_Restaurant == 4:
    Food_Paradise_Restaurant=Restaurant('***Food_Paradise_Restaurant***',100,110,120,130,140,50,60,50,60,70,80)
    Food_Paradise_Restaurant.display()
# Out:
# Enter your name:gvh
# Welcome gvh
# 'Eat what makes you happy'
#
#                                  Press 1  For 'Spice_House_Restaurant'
#                                  Press 2  For 'Lavish_Lounge_Restaurant'
#                                  Press 3  For 'Royal_Spicy_Foods_Restaurant'
#                                  Press 4  For 'Food_Paradise_Restaurant' :
#                                  4
# Restaurant_Name: ***Food_Paradise_Restaurant***
# Manchuria: 100
# Noodles: 110
# Pizza: 120
# Biryani: 130
# Burger: 140
# Cake: 50
# Chaat: 60
# Shawarma: 50
# Shakes: 60
# Sandwich: 70
# Pastry: 80
# .................
